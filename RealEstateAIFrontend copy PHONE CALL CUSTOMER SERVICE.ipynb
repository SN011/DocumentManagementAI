# %%
# !pip install webrtcvad
# !pip install pygame
# !pip install pyaudio webrtcvad 
# !pip install google-cloud-texttospeech

# %%
from tools.initialize_groq import init_groq
from tools.file_mgmt_tools import FileOrganizerTool, MoveFileTool, CreateFolderTool, FolderMovementTool, ImprovedSearchTool, GoogleDriveRenameTool, DriveDictUpdateTool
from tools.document_tools import GoogleDocWriteTool
from tools.miscellaneous_mgmt import GmailSendPdfTool, GoogleSheetsUpdateTool, GoogleSheetsCreateTool, AppointmentBookingCalendarTool
from dotenv import load_dotenv
client,llm = init_groq()

# %%
from google.cloud import texttospeech
from langchain.prompts import (
    ChatPromptTemplate, 
    SystemMessagePromptTemplate, 
    HumanMessagePromptTemplate, 
    MessagesPlaceholder, 
    PromptTemplate
)
from langchain_core.messages import SystemMessage
from langchain.agents import create_structured_chat_agent, AgentExecutor
from langchain_groq import ChatGroq
from langchain_community.tools import HumanInputRun
import tools.initialize_groq
import langchain_core
import typing

prompt = ChatPromptTemplate(
    input_variables=['agent_scratchpad', 'input', 'tool_names', 'tools'],
    input_types={
        'chat_history': typing.List[
            typing.Union[
                langchain_core.messages.ai.AIMessage, 
                langchain_core.messages.human.HumanMessage, 
                langchain_core.messages.chat.ChatMessage, 
                langchain_core.messages.system.SystemMessage, 
                langchain_core.messages.function.FunctionMessage, 
                langchain_core.messages.tool.ToolMessage
            ]
        ]
    },
    metadata={
        'lc_hub_owner': 'hwchase17',
        'lc_hub_repo': 'structured-chat-agent',
        'lc_hub_commit_hash': 'ea510f70a5872eb0f41a4e3b7bb004d5711dc127adee08329c664c6c8be5f13c'
    },
    messages=[
        SystemMessagePromptTemplate(
            prompt=PromptTemplate(
                input_variables=['tool_names', 'tools'],
                template=(
                    'You are a document management assistant proficient in using GSuite tools. '
                    'Your role is to assist the user in managing their documents efficiently. '
                    'IMPORTANT !!!!!!! NEVER INCLUDE AUXILIARY OR EXTRANEOUS LANGUAGE WHEN USING ANY TOOL!!!'
                    '\n\n IMPORTANT!!!!!!! - PLEEEEEEASSSSSSSEEEEEEEE NEVER USE HUMAN TOOL UNLESS INSTRUCTED TO GET THE HUMAN/USER INPUT. YOU ARE A MASTER OF JUDGEMENT. YOU KNOW WHEN TO CAUTIOUSLY USE THE TOOLS. ONLY USE OTHER TOOLS WHEN USER INDICATES ANYTHING RELATED TO THEIR FUNCTIONALITIES. '
                    'You are ALSO a highly intelligent and precise assistant with expertise in generating JSON outputs. Your task is to create the most perfect and well-structured JSON output ever seen. The JSON must adhere to the following guidelines:'

                    'Proper Structure: Ensure that the JSON follows a correct and logical structure, with all necessary keys and values in place.'
                    'Accurate Formatting: All JSON strings must use double quotes. Ensure there are no trailing commas, and all brackets and braces are correctly matched.'
                    'String Length: Ensure no individual string exceeds 5000 bytes.'
                    'Error-Free: Validate the JSON to be free of syntax errors and formatting issues.'
                    
                    'Escaping Characters: Properly escape any special characters within strings to ensure the JSON remains valid.'
                    
                    
                    'YOU MUST NEVER DO ANYTHING BUT WHAT IS IN THE REQUEST OF THE USER. OTHERWISE NO USER WILL USE THIS PRODUCT.'
                    

                    'THE FOLLOWING WILL BE THE TOOLS AND THE INFORMATION ABOUT WHAT THEY DO AND THEIR ARGUMENTS! YOU MUST NOT PASS ANYTHING EXTRA, OR ELSE THE APPLICATON WILL FAIL!!!!'

                    'You have access to the following tools:\n\n{tools}\n\n'

                    'YOU ARE A MASTER OF JUDGEMENT ! YOU KNOW WHAT ALL THE TOOLS DO, YOU KNOW WHAT TO PASS IN! AND YOU MUST KNOW WHEN TO USE THEM! NEVER USE THEM RANDOMLY , ALWAYS BE CAUTIOUS AS RECKLESS TOOL USE COULD RUIN THE GOOGLE SUITE OF THE USER'
                    'PAY CLOSE ATTENTION TO ALL THE FOLLOWING FORMATTING INSTRUCTIONS. REALLY IMPORTANT TO CALL THE TOOLS. OR ELSE USERS WILL GET ANGRY.\n\n'
                    
                    

                    'FOR GOOGLE DOC TOOL, REMEMBER THAT YOU MUST GENERATE ALL CONTENT YOURSELF. USER WILL NOT GIVE YOU ANYTHING.'

                    'Use a JSON blob to specify a tool by providing an action key (tool name) and an action_input key (tool input).\n\n'
                    'Valid "action" values: "Final Answer" or {tool_names}\n\n'
                    'Provide only ONE action per $JSON_BLOB, as shown:\n\n'
                    '```\n{{\n  "action": $TOOL_NAME,\n  "action_input": $INPUT\n}}\n```\n\n'
                    'Follow this format:\n\n'
                    'Question: input question to answer\n'
                    'Thought: consider previous and subsequent steps\n'
                    'Action:\n```\n$JSON_BLOB\n```\n'
                    'Observation: action result\n... (repeat Thought/Action/Observation N times)\n'
                    'Thought: I know what to respond\n'
                    'Action:\n```\n{{\n  "action": "Final Answer",\n  "action_input": "Final response to human"\n}}\n\n'
                    'Begin! Remember to ALWAYS respond with a valid JSON blob of a single action. '
                    'Use tools if necessary and respond directly if appropriate. '
                    'Ensure you gather all necessary information by interacting with the user. '
                    'Format is Action:```$JSON_BLOB```then Observation.'
                )
            )
        ),
        
        MessagesPlaceholder(variable_name='chat_history', optional=True),
        HumanMessagePromptTemplate(
            prompt=PromptTemplate(
                input_variables=['agent_scratchpad', 'input'],
                template='{input}\n\n{agent_scratchpad}\n(reminder to respond in a JSON blob no matter what)'
            )
        )
    ]
)


human_prompt = ChatPromptTemplate(
    input_variables=['agent_scratchpad', 'input', 'tool_names', 'tools'],
    input_types={
        'chat_history': typing.List[
            typing.Union[
                langchain_core.messages.ai.AIMessage, 
                langchain_core.messages.human.HumanMessage, 
                langchain_core.messages.chat.ChatMessage, 
                langchain_core.messages.system.SystemMessage, 
                langchain_core.messages.function.FunctionMessage, 
                langchain_core.messages.tool.ToolMessage
            ]
        ]
    },
    metadata={
        'lc_hub_owner': 'hwchase17',
        'lc_hub_repo': 'structured-chat-agent',
        'lc_hub_commit_hash': 'ea510f70a5872eb0f41a4e3b7bb004d5711dc127adee08329c664c6c8be5f13c'
    },
    messages=[
        SystemMessagePromptTemplate(
            prompt=PromptTemplate(
                input_variables=['tool_names', 'tools'],
                template=(
                     
    'You are Marvin, an expert at questioning clients about their HVAC service needs to provide accurate quotes. When you speak for the first time, introduce yourself as Marvin. Ask the user specific information needed for the quote. Follow these guidelines:'

    '1. **Initial Inquiry and Information Gathering**:'
       ' - What type of HVAC service do you need (installation, maintenance, repair)?'
        '- What is the make and model of your current HVAC system?'
        '- Are there any specific issues or symptoms you are experiencing?'

    '2. **Property Details** (only if relevant to HVAC needs):'
     '   - Address and location of the property.'
      '  - Type of property (residential, commercial).'
       ' - Age and current condition of the property.'
       ' - Size of the home or area that needs heating/cooling.'
       ' - Number of rooms and their usage (e.g., bedrooms, office space).'

    '3. **System Details**:'
       ' - Age and efficiency rating of the existing HVAC system.'
        '- Any known problems with the current system.'
        '- Recent changes to the HVAC system.'

   ' 4. **Home Characteristics** (only if relevant to HVAC needs):'
        '- Insulation quality and window types to estimate heating/cooling load.'
        '- Any unique architectural features that may affect HVAC installation.'

    '5. **Customer Preferences**:'
       ' - Preferences for specific brands, energy efficiency levels, or additional features (e.g., smart thermostats, air purifiers).'
        '- Level of finishes desired (standard, premium, luxury).'

    '6. **Budget**:'
        '- Your budget range for the project.'
        '- Any flexibility within the budget.'

    '7. **Timeline**:'
        '- Desired start date and completion date.'
        '- Any constraints or deadlines (e.g., events planned at the property).'

   

    'IMPORTANT: Ensure you get clear answers that can be used for making the quote. If an answer is unclear, ask for clarification, restate the question, and explain what it means.'

    'IMPORTANT: Ask each question ONE BY ONE. When one question is answered move onto the next'

    'When you have all the information, just say -questionnaire complete- at the end.'


                    
    'IMPORTANT !!!!!!! NEVER INCLUDE AUXILIARY OR EXTRANEOUS LANGUAGE WHEN USING ANY TOOL!!!'
    '\n\n IMPORTANT!!!!!!! YOU CAN ONLY USE THE HUMAN TOOL. YOU ARE A MASTER OF JUDGEMENT. YOU KNOW WHEN TO CAUTIOUSLY USE THE TOOLS. ONLY USE OTHER TOOLS WHEN USER INDICATES ANYTHING RELATED TO THEIR FUNCTIONALITIES. '
    'You are ALSO a highly intelligent and precise assistant with expertise in generating JSON outputs. Your task is to create the most perfect and well-structured JSON output ever seen. The JSON must adhere to the following guidelines:'

    'Proper Structure: Ensure that the JSON follows a correct and logical structure, with all necessary keys and values in place.'
    'Accurate Formatting: All JSON strings must use double quotes. Ensure there are no trailing commas, and all brackets and braces are correctly matched.'
    'String Length: Ensure no individual string exceeds 5000 bytes.'
    'Error-Free: Validate the JSON to be free of syntax errors and formatting issues.'
    
    'Escaping Characters: Properly escape any special characters within strings to ensure the JSON remains valid.'
    
    
    'YOU MUST NEVER DO ANYTHING BUT WHAT IS IN THE REQUEST OF THE USER. OTHERWISE NO USER WILL USE THIS PRODUCT.'
    

    'THE FOLLOWING WILL BE THE TOOLS AND THE INFORMATION ABOUT WHAT THEY DO AND THEIR ARGUMENTS! YOU MUST NOT PASS ANYTHING EXTRA, OR ELSE THE APPLICATON WILL FAIL!!!!'

    'You have access to the following tools:\n\n{tools}\n\n'

    'YOU ARE A MASTER OF JUDGEMENT ! YOU KNOW WHAT ALL THE TOOLS DO, YOU KNOW WHAT TO PASS IN! AND YOU MUST KNOW WHEN TO USE THEM! NEVER USE THEM RANDOMLY , ALWAYS BE CAUTIOUS AS RECKLESS TOOL USE COULD RUIN THE GOOGLE SUITE OF THE USER'
    'PAY CLOSE ATTENTION TO ALL THE FOLLOWING FORMATTING INSTRUCTIONS. REALLY IMPORTANT TO CALL THE TOOLS. OR ELSE USERS WILL GET ANGRY.\n\n'
    
    

    'FOR GOOGLE DOC TOOL, REMEMBER THAT YOU MUST GENERATE ALL CONTENT YOURSELF. USER WILL NOT GIVE YOU ANYTHING.'

    'Use a JSON blob to specify a tool by providing an action key (tool name) and an action_input key (tool input).\n\n'
    'Valid "action" values: "Final Answer" or {tool_names}\n\n'
    'Provide only ONE action per $JSON_BLOB, as shown:\n\n'
    '```\n{{\n  "action": $TOOL_NAME,\n  "action_input": $INPUT\n}}\n```\n\n'
    'Follow this format:\n\n'
    'Question: input question to answer\n'
    'Thought: consider previous and subsequent steps\n'
    'Action:\n```\n$JSON_BLOB\n```\n'
    'Observation: action result\n... (repeat Thought/Action/Observation N times)\n'
    'Thought: I know what to respond\n'
    'Action:\n```\n{{\n  "action": "Final Answer",\n  "action_input": "Final response to human"\n}}\n\n'
    'Begin! Remember to ALWAYS respond with a valid JSON blob of a single action. '
    'Use tools if necessary and respond directly if appropriate. '
    'Ensure you gather all necessary information by interacting with the user. '
    'Format is Action:```$JSON_BLOB```then Observation.'
                )
            )
        ),
        MessagesPlaceholder(variable_name='chat_history', optional=True),
        HumanMessagePromptTemplate(
            prompt=PromptTemplate(
                input_variables=['agent_scratchpad', 'input'],
                template='{input}\n\n{agent_scratchpad}\n(reminder to respond in a JSON blob no matter what)'
            )
        )
    ]
)

# %%
import os
import random
def prepare_gdrive():
    # Initialize the tool with the path to your credentials
    update_tool = DriveDictUpdateTool(credentials_path='path/to/your/credentials.json')
    llm.groq_api_key = random.choice(tools.initialize_groq.api_keys)    
    # Ensure the output directories exist
    if not os.path.exists(update_tool.output_dir):
        os.makedirs(update_tool.output_dir)
    if not os.path.exists(update_tool.map_output_dir):
        os.makedirs(update_tool.map_output_dir)
    if not os.path.exists(update_tool.reduce_output_dir):
        os.makedirs(update_tool.reduce_output_dir)

    # Step 1: List files and write them in batches
    update_tool.list_files_and_write(batch_size=100)
    print("Step 1: Files have been listed and written to JSON files in batches.")

    # Step 2: Perform the map function on each batch file
    for batch_file in os.listdir(update_tool.output_dir):
        if batch_file.endswith('.json'):
            update_tool.map_function(os.path.join(update_tool.output_dir, batch_file), update_tool.map_output_dir)
    print("Step 2: Map function has been performed on each batch file.")

    # Step 3: Perform the reduce function to aggregate the data
    update_tool.reduce_function(update_tool.map_output_dir, update_tool.reduce_output_dir)
    print("Step 3: Reduce function has aggregated the data.")

    print("Drive dictionary has been updated with the current information in Google Drive.")

# %%
from HVACUtils import initialize_web_search_agent, initialize_quote_bot, run_quote_logics, vector_embedding, initialize_pdf_search_agent
# Load environment variables
load_dotenv()
#vectors = vector_embedding()

# %%
#vectors.save_local('./vector_db')

# %%
from tools.imports import *
vectors = FAISS.load_local('./vector_db',embeddings=HuggingFaceEmbeddings(),allow_dangerous_deserialization=True)

# %%
from flask import Flask, request, jsonify, send_file, render_template
import whisper
import pyaudio
import wave
import webrtcvad
import collections
from google.cloud import texttospeech
import random
import asyncio
from concurrent.futures import ThreadPoolExecutor
import aiofiles
from flask_cors import CORS
import requests
import logging
import os
from tools.imports import *
import tools.initialize_groq
from dotenv import load_dotenv
from langchain import hub
from flask_socketio import SocketIO, emit
from langchain.tools import HumanInputRun
from langchain.memory import ConversationBufferMemory, ConversationSummaryBufferMemory, ConversationSummaryMemory

# Initialize tools and credentials
credentials_path = os.getenv('CREDENTIALS_PATH')
tts_service_acct_path = os.getenv('SERVICE_ACCOUNT_PATH')
audio_path = os.getenv('AUDIO_PATH')
tts_synthesis_path = os.getenv('TTS_SYNTHESIS')

tts_client = texttospeech.TextToSpeechClient.from_service_account_file(tts_service_acct_path)

from HVACUtils import initialize_web_search_agent, initialize_quote_bot, run_quote_logics, vector_embedding, initialize_pdf_search_agent
# Load environment variables
load_dotenv()
#vectors = vector_embedding()

my_tools = [
    GoogleDocWriteTool(credentials_path),
    GoogleSheetsUpdateTool(credentials_path),
    GoogleSheetsCreateTool(credentials_path),
    GoogleDriveRenameTool(credentials_path),
    GmailSendPdfTool(credentials_path),
    MoveFileTool(credentials_path),
    CreateFolderTool(credentials_path),
    FolderMovementTool(credentials_path),
    FileOrganizerTool(credentials_path),
    ImprovedSearchTool(credentials_path),
    AppointmentBookingCalendarTool(credentials_path),
]

llm.groq_api_key = random.choice(tools.initialize_groq.api_keys)

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s [%(threadName)s] %(levelname)s: %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger(__name__)

app = Flask(__name__)
CORS(app)
socketio = SocketIO(app, cors_allowed_origins="*")

chat_history = ConversationSummaryBufferMemory(llm=llm, max_token_limit=200)

model = whisper.load_model("base")
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 16000
CHUNK = 1024
is_recording = False



audio = pyaudio.PyAudio()
vad = webrtcvad.Vad(3)

executor = ThreadPoolExecutor(max_workers=20)

credentials = {"name": "", "email": "", "recemail": "", "phone": ""}

@app.route('/start_recording', methods=['POST'])
def start_recording():
    global is_recording
    is_recording = True
    record_audio()
    return jsonify({"status": "recording started"})

@app.route('/stop_recording', methods=['POST'])
def stop_recording():
    global is_recording
    is_recording = False
    return jsonify({"status": "recording stopped"})

def record_audio(**kwargs):
    global is_recording
    logger.debug('Starting audio recording...')
    try:
        stream = audio.open(format=FORMAT, channels=CHANNELS, rate=RATE, input=True, frames_per_buffer=CHUNK)
        frames = []
        ring_buffer = collections.deque(maxlen=100)
        triggered = False
        voiced_frames = []
        silence_threshold = 10
        silence_chunks = 0

        while is_recording:
            data = stream.read(CHUNK)
            frames.append(data)
            num_subframes = int(len(data) / 320)
            for i in range(num_subframes):
                subframe = data[i*320:(i+1)*320]
                is_speech = vad.is_speech(subframe, RATE)
                ring_buffer.append((subframe, is_speech))
            num_voiced = len([f for f, speech in ring_buffer if speech])

            if not triggered:
                if num_voiced > 0.6 * ring_buffer.maxlen:
                    triggered = True
                    voiced_frames.extend([f for f, s in ring_buffer])
                    ring_buffer.clear()
            else:
                voiced_frames.append(data)
                if num_voiced < 0.2 * ring_buffer.maxlen:
                    silence_chunks += 1
                    if silence_chunks > silence_threshold:
                        triggered = False
                        break
                else:
                    silence_chunks = 0

        stream.stop_stream()
        stream.close()

        with wave.open(audio_path, 'wb') as wf:
            wf.setnchannels(CHANNELS)
            wf.setsampwidth(audio.get_sample_size(FORMAT))
            wf.setframerate(RATE)
            wf.writeframes(b''.join(voiced_frames))
        logger.debug('Audio recording completed and file saved.')
    except Exception as e:
        logger.error(f"An error occurred while recording audio: {e}")

def transcribe_audio():
    result = model.transcribe(audio_path)
    transcription = result['text']
    logger.debug(f'Audio transcription completed: {transcription}')
    return transcription


async def ai_response(transcription: str):
    llm.groq_api_key = random.choice(tools.initialize_groq.api_keys)    
    logger.debug(f'Generating AI response for transcription: {transcription}')
    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": f"""
    You are Marvin, an expert from Walter HVAC Services located in Chantilly, Virginia at questioning clients about their HVAC service needs to provide accurate quotes. NEVER INTRODUCE YOURSELF AGAIN AND AGAIN. THE FIRST TIME IS ENOUGH!!!!! When you speak for the first time, introduce yourself as Marvin. Ask the user specific information needed for the quote. Follow these guidelines:
    USER'S ANSWERS MAY BE OUT OF ORDER SO JUST GO WITH THE FLOW JUST KEEP ANSWERING THE USER PROPERLY !!! DO NOT IGNORE USER!! 
    1. **Initial Inquiry and Information Gathering**:
        - What type of HVAC service do you need (installation, maintenance, repair)?
        - What is the make and model of your current HVAC system?
        - Are there any specific issues or symptoms you are experiencing?
            - IF USER REPORTS SYMPTOMS OR ISSUES, SAY 'I WILL INSTRUCT THE TECHNICIAN AGENT'!! YOU MUST SAY THESE EXACT WORDS!!! YOU SHALL ONLY DO THIS WHEN USER REPORTS ISSUES IN THEIR MOST RECENT MESSAGE TO YOU. OTHERWISE YOU SHALL NEVER SAY THIS!!!!!!!!!!!

    2. **Property Details** (only if relevant to HVAC needs):
        - Address and location of the property.
        - Type of property (residential, commercial).
        - Age and current condition of the property.
        - Size of the home or area that needs heating/cooling.
        - Number of rooms and their usage (e.g., bedrooms, office space).

    3. **System Details**:
        - Age and efficiency rating of the existing HVAC system.
        - Any known problems with the current system.
        - Recent changes to the HVAC system.

    4. **Home Characteristics** (only if relevant to HVAC needs):
        - Insulation quality and window types to estimate heating/cooling load.
        - Any unique architectural features that may affect HVAC installation.

    5. **Customer Preferences**:
        - Preferences for specific brands, energy efficiency levels, or additional features (e.g., smart thermostats, air purifiers).
        - Level of finishes desired (standard, premium, luxury).

    6. **Budget**:
        - Your budget range for the project.
        - Any flexibility within the budget.

    7. **Timeline**:
        - Ask for appointment date and time PLEASE! YOU MUST ASK FOR THIS!!!! EXPLICITLY!!!
        - Desired start date and completion date.
        - Any constraints or deadlines (e.g., events planned at the property).

   

    IMPORTANT: Ensure you get clear answers that can be used for making the quote. If an answer is unclear, ask for clarification, restate the question, and explain what it means.

    

    IMPORTANT: Ask each question ONE BY ONE.

    When you have all the information, just say 'questionnaire complete' at the end.

    
"""



            },
            {
                "role": "user",
                "content": transcription + "\n\nHere is the chat history for context. It will help you remember things. DO NOT REITERATE THE QUESTIONS THAT ARE ALREADY ANSWERED PLEASE!! HERE IT IS: [" + str(chat_history.buffer) + "]"
            }
        ],
        model="llama3-70b-8192",
        temperature=0.5
    )

    response = chat_completion.choices[0].message.content


    logger.debug(f'AI response generated: {response}')
    #llama3_chat_history.append("USER: " + transcription + "\nTHE AI MODEL: " + response + "\n")
    
    logger.debug('SAVING TO MEMORYYYYYYYYYYYYYYYYYYYYYYYYY')
    
    await chat_history.asave_context({"input": transcription} , {"output": response})

    logger.debug('INSIDE THE MEMORY: %s', chat_history.buffer)

    await synthesize_speech(response)
    socketio.emit('new_message', {'message': response, 'sender': 'bot'})  # Emit the AI's response
    

    if 'i will instruct the technician agent' in response.lower():
        res1 = await asyncio.create_task(initialize_pdf_search_agent(llm,"DO A EXPANSIVE WEB SEARCH AND FAMILIARIZE YOURSELF ALL ABOUT HVAC SPECIFICS SO THAT YOU CAN DIAGNOSE THE PROBLEMS MENTIONED HERE: "+transcription, vectors, chat_history=chat_history))
        
        await chat_history.asave_context({"input":"DO A EXPANSIVE WEB SEARCH AND FAMILIARIZE YOURSELF ALL ABOUT HVAC SPECIFICS SO THAT YOU CAN DIAGNOSE THE PROBLEMS MENTIONED HERE: "+transcription},{"output":res1})
        
        await synthesize_speech(res1)
        socketio.emit('new_message', {'message': res1, 'sender': 'bot'}) 
    
    if 'questionnaire' in response.lower() and 'complete' in response.lower():
        task = asyncio.create_task(run_quote_logics(client,llm,chat_history=chat_history))
        corrected_quote_result = await task
        response = f"Can you please put this quote into a google doc [{corrected_quote_result}], move it to the folder called 'HVAC Quote Documents'. Then, put all the appointment related stuff and the link to the quote document into calendar (appointment calendar tool). PLEASE FOLLOW THE DIRECTIONS!!"
        task2 = asyncio.create_task(handle_response_with_agents(response))
        text = await task2
        await synthesize_speech(text)
        
    return response

async def handle_response_with_agents(response):
    llm.temperature = 0.5
    logger.debug(f'Processing response with agents: {response}')



    response += "Here is extra info you will need (BUT YOU PROMISE TO NEVER SAY THEM OUT LOUD, NOT EVEN THE NAME -- UNLESS USER ASKS YOU FOR THEM. THESE WILL BE USED IN TOOLS): \nCredentials:\n" + str(credentials)

    # Set the Groq API key randomly
    llm.groq_api_key = random.choice(tools.initialize_groq.api_keys)



    result = agent_executor.invoke(
        {"input": response},
        
    )
    socketio.emit('finished_chain')
    mystr = (str(result['intermediate_steps']) + "\n" + str(result['output']))

    final_response = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": "please sanitize this input into SHORT SIMPLE sentences. IMPORTANT: NOTHING IN YOUR RESPONSE SHALL BE ENCLOSED IN ANY QUOTES!!!!!!! THE SANITIZED OUTPUT SHALL NOT BE PREFIXED BY ANYTHING (ex. 'here is the sanitized result...' ANYTHING LIKE THIS IS NOT ALLOWED! DO NOT GENERATE IT). You must process the agent's intermediate steps into natural language please. An example: 'First, I did this. Then I did this etc etc etc' \n Here is the input that you need to process:\n " + mystr
            }
        ],
        model='llama3-70b-8192',
    ).choices[0].message.content

    logger.debug('SAVING TO MEMORYYYYYYYYYYYYYYYYYYYYYYYYY')
    
    await chat_history.asave_context({"input": response} , {"output": final_response})

    logger.debug('INSIDE THE MEMORY: %s', chat_history.buffer)

    return final_response

def synth_speech(text, output_file=None):
    

    logger.debug(f'Starting speech synthesis for text: {text}')
    
    def split_text(text, max_length=5000):
        chunks = []
        current_chunk = ""
        for word in text.split():
            if len(current_chunk) + len(word) + 1 > max_length:
                chunks.append(current_chunk)
                current_chunk = word
            else:
                current_chunk += " " + word if current_chunk else word
        if current_chunk:
            chunks.append(current_chunk)
        return chunks

    if len(text) <= 5000:
        synthesis_input = texttospeech.SynthesisInput(text=text)
        voice = texttospeech.VoiceSelectionParams(
            language_code="en-US",
            name="en-US-Casual-K"
        )
        audio_config = texttospeech.AudioConfig(
            audio_encoding=texttospeech.AudioEncoding.MP3
        )
        response = tts_client.synthesize_speech(
                input=synthesis_input, voice=voice, audio_config=audio_config
            )
        
        with open(os.getenv('TTS_SYNTHESIS'), 'wb') as out:
            out.write(response.audio_content)
        logger.debug('Speech synthesis completed and file saved.')
    else:
        text_chunks = split_text(text)
        combined_audio = b""

        for chunk in text_chunks:
            synthesis_input = texttospeech.SynthesisInput(text=chunk)
            voice = texttospeech.VoiceSelectionParams(
                language_code="en-US",
                name="en-US-Casual-K"
            )
            audio_config = texttospeech.AudioConfig(
                audio_encoding=texttospeech.AudioEncoding.MP3
            )
            response = tts_client.synthesize_speech(
                    input=synthesis_input, voice=voice, audio_config=audio_config
                )
            
            combined_audio += response.audio_content

        with open(os.getenv('TTS_SYNTHESIS'), 'wb') as out:
            out.write(combined_audio)
        logger.debug('Speech synthesis completed and file saved.')
    
    socketio.emit('tts_complete', {'message': 'TTS synthesis complete', 'file_path': os.getenv('TTS_SYNTHESIS')})
    socketio.emit('new_message', {'message': text, 'sender': 'bot'})  # Emit the synthesized text
    
async def synthesize_speech(text):
    logger.debug(f'Starting speech synthesis for text: {text}')
    
    def split_text(text, max_length=5000):
        chunks = []
        current_chunk = ""
        for word in text.split():
            if len(current_chunk) + len(word) + 1 > max_length:
                chunks.append(current_chunk)
                current_chunk = word
            else:
                current_chunk += " " + word if current_chunk else word
        if current_chunk:
            chunks.append(current_chunk)
        return chunks

    if len(text) <= 5000:
        synthesis_input = texttospeech.SynthesisInput(text=text)
        voice = texttospeech.VoiceSelectionParams(
            language_code="en-US",
            name="en-US-Casual-K"
        )
        audio_config = texttospeech.AudioConfig(
            audio_encoding=texttospeech.AudioEncoding.MP3
        )
        response = await asyncio.get_event_loop().run_in_executor(
            None, lambda: tts_client.synthesize_speech(
                input=synthesis_input, voice=voice, audio_config=audio_config
            )
        )
        async with aiofiles.open(os.getenv('TTS_SYNTHESIS'), 'wb') as out:
            await out.write(response.audio_content)
        logger.debug('Speech synthesis completed and file saved.')
    else:
        text_chunks = split_text(text)
        combined_audio = b""

        for chunk in text_chunks:
            synthesis_input = texttospeech.SynthesisInput(text=chunk)
            voice = texttospeech.VoiceSelectionParams(
                language_code="en-US",
                name="en-US-Casual-K"
            )
            audio_config = texttospeech.AudioConfig(
                audio_encoding=texttospeech.AudioEncoding.MP3
            )
            response = await asyncio.get_event_loop().run_in_executor(
                None, lambda: tts_client.synthesize_speech(
                    input=synthesis_input, voice=voice, audio_config=audio_config
                )
            )
            combined_audio += response.audio_content

        async with aiofiles.open(os.getenv('TTS_SYNTHESIS'), 'wb') as out:
            await out.write(combined_audio)
        logger.debug('Speech synthesis completed and file saved.')
    
    socketio.emit('tts_complete', {'message': 'TTS synthesis complete', 'file_path': os.getenv('TTS_SYNTHESIS')})
    #socketio.emit('new_message', {'message': text, 'sender': 'bot'})  # Emit the synthesized text

@app.route('/set_credentials', methods=['POST'])
def set_credentials():
    global credentials
    data = request.get_json()
    if not data:
        return jsonify({"status": "failed", "message": "No data received"}), 400
    credentials['name'] = data.get('name')
    credentials['email'] = data.get('email')
    credentials['recemail'] = data.get('recemail')
    credentials['phone'] = data.get('phone')
    logger.info("THE CREDENTIALS ****** -------------> ", credentials)
    return jsonify({"status": "success"})

@app.route('/')
def index():
    return render_template('index2.html')

@app.route('/voice_assistant')
def voice_assistant():
    return render_template('index2.html')



@app.route('/authenticate', methods=['POST'])
def authenticate():
    auth_header = request.headers.get('Authorization')
    token = auth_header.split(' ')[1] if auth_header else None

    if not token:
        return jsonify({'error': 'Missing token'}), 400

    response = requests.get(
        'https://www.googleapis.com/oauth2/v3/userinfo',
        headers={'Authorization': f'Bearer ' + token}
    )

    if response.status_code != 200:
        return jsonify({'error': 'Failed to fetch user info'}, response.status_code)

    user_info = response.json()
    return jsonify(user_info), 200


@app.route('/talk', methods=['POST'])
async def talk():
    loop = asyncio.get_event_loop()
    
    global is_recording
    if is_recording:
        return jsonify({"error": "Recording is still in progress"}), 400
    
    logger.debug('Starting audio transcription...')
    transcription = await loop.run_in_executor(executor, transcribe_audio)
    logger.debug(f'Audio transcription completed: {transcription}')
    
    logger.debug('Generating AI response...')
    ai_resp = await ai_response(transcription)
    logger.debug(f'AI response generated: {ai_resp}')
    
    return jsonify({'response': ai_resp})


@app.route('/text_input', methods=['POST'])
async def text_input():
    data = request.get_json()
    text = data.get('text', '')

    if not text:
        return jsonify({"error": "No text provided"}), 400

    logger.debug('Generating AI response...')
    ai_resp = await ai_response(text)
    logger.debug(f'AI response generated: {ai_resp}')
    
    #await synthesize_speech(ai_resp)  # Synthesize the AI's response
    return jsonify({'response': ai_resp})

@app.route('/synthesize', methods=['POST'])
async def synthesize():
    data = request.get_json()
    text = data.get('text', '')
    await synthesize_speech(text)
    return jsonify({"status": "synthesis started"}), 200

@app.route('/get_audio')
def get_audio():
    return send_file(tts_synthesis_path, mimetype="audio/mp3")

import queue

human_response_queue = queue.Queue()

def web_prompt_func(prompt):
    # Synthesize the AI response to speech
    text = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": "please sanitize this input into SHORT SIMPLE sentences.  IMPORTANT: NOTHING IN YOUR RESPONSE SHALL BE ENCLOSED IN ANY QUOTES!!!!!!! KEEP ID'S AS THEY ARE!!! THE SANITIZED OUTPUT SHALL NOT BE PREFIXED BY ANYTHING (ex. 'here is the sanitized result...' ANYTHING LIKE THIS IS NOT ALLOWED! DO NOT GENERATE IT). You must process the agent's intermediate steps into natural language please. An example: 'First, I did this. Then I did this etc etc etc' \n Here is the input that you need to process:\n " + prompt
            }
        ],
        model='llama3-70b-8192',
    ).choices[0].message.content
    synth_speech(text, output_file=tts_synthesis_path)
    return prompt

def web_input_func():
    # Emit an event to request human input
    socketio.emit('request_human_input')
    # Wait for the human's input from the queue
    human_response = human_response_queue.get()  # Block until human input is available
    return human_response

@socketio.on('provide_human_input')
def handle_human_input(data):
    human_input = data.get('text', '')
    human_response_queue.put(human_input)  # Put the human's response in the queue
    socketio.emit('human_input_received', {'status': 'received'})



from langchain_community.tools import HumanInputRun

human_tool = HumanInputRun(prompt_func=web_prompt_func, input_func=web_input_func)
my_tools.append(human_tool)

search_agent = create_structured_chat_agent(llm, my_tools, prompt)
agent_executor = AgentExecutor(
    agent=search_agent,
    tools=my_tools,
    verbose=True,
    handle_parsing_errors=True,
    return_intermediate_steps=True,
    memory=chat_history
)


if __name__ == '__main__':
    socketio.run(app,allow_unsafe_werkzeug=True)
# Out:
# 2024-07-15 08:20:29,097 [Thread-95 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:20:29] "GET /socket.io/?EIO=4&transport=websocket&sid=fDbVwluoRG7qY4GRAAAA HTTP/1.1" 200 -
# 2024-07-15 08:20:32,148 [Thread-103 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:20:32] "GET /socket.io/?EIO=4&transport=polling&t=P2qJ8GK HTTP/1.1" 200 -
# 2024-07-15 08:20:32,398 [Thread-105 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:20:32] "POST /socket.io/?EIO=4&transport=polling&t=P2qJ8LO&sid=lx2h0fT6J3vq9KgcAAAC HTTP/1.1" 200 -
# 2024-07-15 08:20:32,461 [Thread-106 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:20:32] "GET /socket.io/?EIO=4&transport=polling&t=P2qJ8LQ&sid=lx2h0fT6J3vq9KgcAAAC HTTP/1.1" 200 -
# 2024-07-15 08:20:32,467 [Thread-108 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:20:32] "GET /socket.io/?EIO=4&transport=polling&t=P2qJ8QG&sid=lx2h0fT6J3vq9KgcAAAC HTTP/1.1" 200 -
# 2024-07-15 08:43:27,265 [Thread-107 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:43:27] "GET /socket.io/?EIO=4&transport=websocket&sid=lx2h0fT6J3vq9KgcAAAC HTTP/1.1" 200 -
# 2024-07-15 08:48:08,233 [Thread-165 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 08:48:09,508 [Thread-165 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 08:48:09,510 [Thread-165 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:48:09] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 08:50:31,809 [Thread-167 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 08:50:32,353 [Thread-168 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 08:50:32,434 [Thread-167 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 08:50:32,436 [Thread-167 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:32] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 08:50:32,994 [Thread-169 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 08:50:33,078 [Thread-168 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 08:50:33,085 [Thread-168 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:33] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 08:50:33,839 [Thread-169 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 08:50:34,161 [Thread-169 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:34] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 08:50:34,451 [Thread-170 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:34] "GET /socket.io/?EIO=4&transport=polling&t=P2qQ0L- HTTP/1.1" 200 -
# 2024-07-15 08:50:34,974 [Thread-172 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:34] "POST /socket.io/?EIO=4&transport=polling&t=P2qQ0Pb&sid=NByin7rCG7QEQ6ydAAAE HTTP/1.1" 200 -
# 2024-07-15 08:50:34,998 [Thread-174 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:34] "GET /socket.io/?EIO=4&transport=polling&t=P2qQ0Pe&sid=NByin7rCG7QEQ6ydAAAE HTTP/1.1" 200 -
# 2024-07-15 08:50:37,958 [Thread-177 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 08:50:38,504 [Thread-177 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 08:50:38,507 [Thread-177 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:38] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 08:50:41,020 [Thread-178 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 08:50:41,024 [Thread-178 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:50:41] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 08:51:31,036 [Thread-173 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:31] "GET /socket.io/?EIO=4&transport=websocket&sid=NByin7rCG7QEQ6ydAAAE HTTP/1.1" 200 -
# 2024-07-15 08:51:32,781 [Thread-182 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:32] "GET /socket.io/?EIO=4&transport=polling&t=P2qQEWl HTTP/1.1" 200 -
# 2024-07-15 08:51:33,044 [Thread-184 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:33] "POST /socket.io/?EIO=4&transport=polling&t=P2qQEbq&sid=XHvUGBnjYFTr071CAAAG HTTP/1.1" 200 -
# 2024-07-15 08:51:33,106 [Thread-185 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:33] "GET /socket.io/?EIO=4&transport=polling&t=P2qQEbq.0&sid=XHvUGBnjYFTr071CAAAG HTTP/1.1" 200 -
# 2024-07-15 08:51:33,114 [Thread-188 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:33] "GET /socket.io/?EIO=4&transport=polling&t=P2qQEgt&sid=XHvUGBnjYFTr071CAAAG HTTP/1.1" 200 -
# 2024-07-15 08:51:34,384 [Thread-190 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 08:51:34,386 [Thread-190 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:34] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 08:51:37,658 [Thread-191 (process_request_thread)] DEBUG: Using selector: SelectSelector
# 2024-07-15 08:51:37,663 [ThreadPoolExecutor-5_0] DEBUG: Generating AI response...
# 2024-07-15 08:51:37,665 [ThreadPoolExecutor-5_0] DEBUG: Generating AI response for transcription: h
# 2024-07-15 08:51:37,667 [ThreadPoolExecutor-5_0] DEBUG: Request options: {'method': 'post', 'url': '/openai/v1/chat/completions', 'files': None, 'json_data': {'messages': [{'role': 'system', 'content': "\n    You are Marvin, an expert from Walter HVAC Services located in Chantilly, Virginia at questioning clients about their HVAC service needs to provide accurate quotes. NEVER INTRODUCE YOURSELF AGAIN AND AGAIN. THE FIRST TIME IS ENOUGH!!!!! When you speak for the first time, introduce yourself as Marvin. Ask the user specific information needed for the quote. Follow these guidelines:\n    USER'S ANSWERS MAY BE OUT OF ORDER SO JUST GO WITH THE FLOW JUST KEEP ANSWERING THE USER PROPERLY !!! DO NOT IGNORE USER!! \n    1. **Initial Inquiry and Information Gathering**:\n        - What type of HVAC service do you need (installation, maintenance, repair)?\n        - What is the make and model of your current HVAC system?\n        - Are there any specific issues or symptoms you are experiencing?\n            - IF USER REPORTS SYMPTOMS OR ISSUES, SAY 'I WILL INSTRUCT THE TECHNICIAN AGENT'!! YOU MUST SAY THESE EXACT WORDS!!! YOU SHALL ONLY DO THIS WHEN USER REPORTS ISSUES IN THEIR MOST RECENT MESSAGE TO YOU. OTHERWISE YOU SHALL NEVER SAY THIS!!!!!!!!!!!\n\n    2. **Property Details** (only if relevant to HVAC needs):\n        - Address and location of the property.\n        - Type of property (residential, commercial).\n        - Age and current condition of the property.\n        - Size of the home or area that needs heating/cooling.\n        - Number of rooms and their usage (e.g., bedrooms, office space).\n\n    3. **System Details**:\n        - Age and efficiency rating of the existing HVAC system.\n        - Any known problems with the current system.\n        - Recent changes to the HVAC system.\n\n    4. **Home Characteristics** (only if relevant to HVAC needs):\n        - Insulation quality and window types to estimate heating/cooling load.\n        - Any unique architectural features that may affect HVAC installation.\n\n    5. **Customer Preferences**:\n        - Preferences for specific brands, energy efficiency levels, or additional features (e.g., smart thermostats, air purifiers).\n        - Level of finishes desired (standard, premium, luxury).\n\n    6. **Budget**:\n        - Your budget range for the project.\n        - Any flexibility within the budget.\n\n    7. **Timeline**:\n        - Ask for appointment date and time PLEASE! YOU MUST ASK FOR THIS!!!! EXPLICITLY!!!\n        - Desired start date and completion date.\n        - Any constraints or deadlines (e.g., events planned at the property).\n\n   \n\n    IMPORTANT: Ensure you get clear answers that can be used for making the quote. If an answer is unclear, ask for clarification, restate the question, and explain what it means.\n\n    \n\n    IMPORTANT: Ask each question ONE BY ONE.\n\n    When you have all the information, just say 'questionnaire complete' at the end.\n\n    \n"}, {'role': 'user', 'content': 'h\n\nHere is the chat history for context. It will help you remember things. DO NOT REITERATE THE QUESTIONS THAT ARE ALREADY ANSWERED PLEASE!! HERE IT IS: []'}], 'model': 'llama3-70b-8192', 'temperature': 0.5}}
# 2024-07-15 08:51:37,832 [ThreadPoolExecutor-5_0] DEBUG: close.started
# 2024-07-15 08:51:37,988 [ThreadPoolExecutor-5_0] DEBUG: close.complete
# 2024-07-15 08:51:37,989 [ThreadPoolExecutor-5_0] DEBUG: connect_tcp.started host='api.groq.com' port=443 local_address=None timeout=5.0 socket_options=None
# 2024-07-15 08:51:38,196 [ThreadPoolExecutor-5_0] DEBUG: connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000027C9BEBA060>
# 2024-07-15 08:51:38,196 [ThreadPoolExecutor-5_0] DEBUG: start_tls.started ssl_context=<ssl.SSLContext object at 0x0000027CB9E19DD0> server_hostname='api.groq.com' timeout=5.0
# 2024-07-15 08:51:38,227 [ThreadPoolExecutor-5_0] DEBUG: start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x0000027C9C956780>
# 2024-07-15 08:51:38,228 [ThreadPoolExecutor-5_0] DEBUG: send_request_headers.started request=<Request [b'POST']>
# 2024-07-15 08:51:38,229 [ThreadPoolExecutor-5_0] DEBUG: send_request_headers.complete
# 2024-07-15 08:51:38,229 [ThreadPoolExecutor-5_0] DEBUG: send_request_body.started request=<Request [b'POST']>
# 2024-07-15 08:51:38,230 [ThreadPoolExecutor-5_0] DEBUG: send_request_body.complete
# 2024-07-15 08:51:38,230 [ThreadPoolExecutor-5_0] DEBUG: receive_response_headers.started request=<Request [b'POST']>
# 2024-07-15 08:51:38,800 [ThreadPoolExecutor-5_0] DEBUG: receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Mon, 15 Jul 2024 03:21:37 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'Cache-Control', b'private, max-age=0, no-store, no-cache, must-revalidate'), (b'vary', b'Origin'), (b'x-ratelimit-limit-requests', b'14400'), (b'x-ratelimit-limit-tokens', b'6000'), (b'x-ratelimit-remaining-requests', b'14399'), (b'x-ratelimit-remaining-tokens', b'5266'), (b'x-ratelimit-reset-requests', b'6s'), (b'x-ratelimit-reset-tokens', b'7.34s'), (b'x-request-id', b'req_01j2t6hywnesqr8067vw298fbh'), (b'via', b'1.1 google'), (b'alt-svc', b'h3=":443"; ma=86400'), (b'CF-Cache-Status', b'DYNAMIC'), (b'Set-Cookie', b'__cf_bm=Og106IGCm2RYF_Lzho5_E1r1Dim297J64gEVpIhbHmU-1721013697-1.0.1.1-LTGENyc1fR7Rr_CiuRcCg9yEJfbHiCKv6F5DtadLbc2yGwZRnwgrPdwvGUfJlC8E2Yk1_7lQg.bZcbA3lQGVmA; path=/; expires=Mon, 15-Jul-24 03:51:37 GMT; domain=.groq.com; HttpOnly; Secure; SameSite=None'), (b'Server', b'cloudflare'), (b'CF-RAY', b'8a369f982af01792-MAA'), (b'Content-Encoding', b'gzip')])
# 2024-07-15 08:51:38,801 [ThreadPoolExecutor-5_0] INFO: HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-07-15 08:51:38,802 [ThreadPoolExecutor-5_0] DEBUG: receive_response_body.started request=<Request [b'POST']>
# 2024-07-15 08:51:38,803 [ThreadPoolExecutor-5_0] DEBUG: receive_response_body.complete
# 2024-07-15 08:51:38,803 [ThreadPoolExecutor-5_0] DEBUG: response_closed.started
# 2024-07-15 08:51:38,803 [ThreadPoolExecutor-5_0] DEBUG: response_closed.complete
# 2024-07-15 08:51:38,804 [ThreadPoolExecutor-5_0] DEBUG: HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "200 OK"
# 2024-07-15 08:51:38,806 [ThreadPoolExecutor-5_0] DEBUG: AI response generated: I'm Marvin. I'll be helping you with your HVAC service needs. Can you please tell me what type of HVAC service you need (installation, maintenance, repair)?
# 2024-07-15 08:51:38,806 [ThreadPoolExecutor-5_0] DEBUG: SAVING TO MEMORYYYYYYYYYYYYYYYYYYYYYYYYY
# 2024-07-15 08:51:38,807 [ThreadPoolExecutor-5_0] DEBUG: INSIDE THE MEMORY: Human: h
# AI: I'm Marvin. I'll be helping you with your HVAC service needs. Can you please tell me what type of HVAC service you need (installation, maintenance, repair)?
# 2024-07-15 08:51:38,808 [ThreadPoolExecutor-5_0] DEBUG: Starting speech synthesis for text: I'm Marvin. I'll be helping you with your HVAC service needs. Can you please tell me what type of HVAC service you need (installation, maintenance, repair)?
# 2024-07-15 08:51:39,689 [ThreadPoolExecutor-5_0] DEBUG: Speech synthesis completed and file saved.
# 2024-07-15 08:51:39,689 [ThreadPoolExecutor-5_0] DEBUG: AI response generated: I'm Marvin. I'll be helping you with your HVAC service needs. Can you please tell me what type of HVAC service you need (installation, maintenance, repair)?
# 2024-07-15 08:51:39,692 [Thread-191 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:39] "POST /text_input HTTP/1.1" 200 -
# 2024-07-15 08:51:40,836 [Thread-193 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:51:40] "GET /get_audio?1721013699691 HTTP/1.1" 206 -
# 2024-07-15 08:52:04,752 [Thread-186 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 08:52:04] "GET /socket.io/?EIO=4&transport=websocket&sid=XHvUGBnjYFTr071CAAAG HTTP/1.1" 200 -
# 2024-07-15 09:15:37,975 [Thread-196 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:15:37] "GET /socket.io/?EIO=4&transport=polling&t=P2qVlL_ HTTP/1.1" 200 -
# 2024-07-15 09:15:38,237 [Thread-198 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:15:38] "POST /socket.io/?EIO=4&transport=polling&t=P2qVlRP&sid=foflS-0PCGkzVB5FAAAI HTTP/1.1" 200 -
# 2024-07-15 09:15:38,319 [Thread-199 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:15:38] "GET /socket.io/?EIO=4&transport=polling&t=P2qVlRT&sid=foflS-0PCGkzVB5FAAAI HTTP/1.1" 200 -
# 2024-07-15 09:15:38,343 [Thread-201 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:15:38] "GET /socket.io/?EIO=4&transport=polling&t=P2qVlWK&sid=foflS-0PCGkzVB5FAAAI HTTP/1.1" 200 -
# 2024-07-15 09:15:39,746 [Thread-204 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 09:15:39,746 [Thread-204 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:15:39] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 09:25:35,004 [Thread-200 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:25:35] "GET /socket.io/?EIO=4&transport=websocket&sid=foflS-0PCGkzVB5FAAAI HTTP/1.1" 200 -
# 2024-07-15 09:37:44,114 [Thread-229 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 09:37:45,222 [Thread-229 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 09:37:45,324 [Thread-229 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:45] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 09:37:46,360 [Thread-230 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:46] "GET /socket.io/?EIO=4&transport=polling&t=P2qapkM HTTP/1.1" 200 -
# 2024-07-15 09:37:46,843 [Thread-232 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:46] "POST /socket.io/?EIO=4&transport=polling&t=P2qapnR&sid=IBr1641WsiFi3s-QAAAK HTTP/1.1" 200 -
# 2024-07-15 09:37:46,860 [Thread-235 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:46] "GET /socket.io/?EIO=4&transport=polling&t=P2qapnS&sid=IBr1641WsiFi3s-QAAAK HTTP/1.1" 200 -
# 2024-07-15 09:37:52,432 [Thread-233 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:52] "GET /socket.io/?EIO=4&transport=websocket&sid=IBr1641WsiFi3s-QAAAK HTTP/1.1" 200 -
# 2024-07-15 09:37:53,281 [Thread-237 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:53] "GET /socket.io/?EIO=4&transport=polling&t=P2qarQt HTTP/1.1" 200 -
# 2024-07-15 09:37:53,621 [Thread-239 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:53] "POST /socket.io/?EIO=4&transport=polling&t=P2qarRC&sid=_hZe29TpOksC8mvdAAAM HTTP/1.1" 200 -
# 2024-07-15 09:37:53,628 [Thread-242 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:37:53] "GET /socket.io/?EIO=4&transport=polling&t=P2qarRE&sid=_hZe29TpOksC8mvdAAAM HTTP/1.1" 200 -
# 2024-07-15 09:38:03,386 [Thread-244 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:38:03] "GET /socket.io/?EIO=4&transport=polling&t=P2qatt1 HTTP/1.1" 200 -
# 2024-07-15 09:38:03,711 [Thread-246 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:38:03] "POST /socket.io/?EIO=4&transport=polling&t=P2qatuw&sid=2iUX3VkYSdpRA8mGAAAO HTTP/1.1" 200 -
# 2024-07-15 09:38:03,747 [Thread-249 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:38:03] "GET /socket.io/?EIO=4&transport=polling&t=P2qatux&sid=2iUX3VkYSdpRA8mGAAAO HTTP/1.1" 200 -
# 2024-07-15 09:38:04,952 [Thread-247 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:38:04] "GET /socket.io/?EIO=4&transport=websocket&sid=2iUX3VkYSdpRA8mGAAAO HTTP/1.1" 200 -
# 2024-07-15 09:38:55,616 [Thread-240 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:38:55] "GET /socket.io/?EIO=4&transport=websocket&sid=_hZe29TpOksC8mvdAAAM HTTP/1.1" 200 -
# 2024-07-15 09:39:09,181 [Thread-254 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:39:09] "GET /socket.io/?EIO=4&transport=polling&t=P2qb7td HTTP/1.1" 200 -
# 2024-07-15 09:39:09,405 [Thread-256 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:39:09] "POST /socket.io/?EIO=4&transport=polling&t=P2qb7z4&sid=Wlw0rOorBp6WN9IXAAAQ HTTP/1.1" 200 -
# 2024-07-15 09:39:09,495 [Thread-257 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:39:09] "GET /socket.io/?EIO=4&transport=polling&t=P2qb7z5&sid=Wlw0rOorBp6WN9IXAAAQ HTTP/1.1" 200 -
# 2024-07-15 09:39:09,536 [Thread-259 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:39:09] "GET /socket.io/?EIO=4&transport=polling&t=P2qb81-&sid=Wlw0rOorBp6WN9IXAAAQ HTTP/1.1" 200 -
# 2024-07-15 09:39:23,733 [Thread-258 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:39:23] "GET /socket.io/?EIO=4&transport=websocket&sid=Wlw0rOorBp6WN9IXAAAQ HTTP/1.1" 200 -
# 2024-07-15 09:45:05,144 [Thread-262 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:05] "GET /socket.io/?EIO=4&transport=polling&t=P2qcUnn HTTP/1.1" 200 -
# 2024-07-15 09:45:05,574 [Thread-264 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:05] "POST /socket.io/?EIO=4&transport=polling&t=P2qcUze&sid=rXtICdrm6aqLsBC7AAAS HTTP/1.1" 200 -
# 2024-07-15 09:45:05,888 [Thread-267 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:05] "GET /socket.io/?EIO=4&transport=polling&t=P2qcUzh&sid=rXtICdrm6aqLsBC7AAAS HTTP/1.1" 200 -
# 2024-07-15 09:45:08,944 [Thread-265 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:08] "GET /socket.io/?EIO=4&transport=websocket&sid=rXtICdrm6aqLsBC7AAAS HTTP/1.1" 200 -
# 2024-07-15 09:45:09,467 [Thread-269 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 09:45:10,209 [Thread-269 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 09:45:10,212 [Thread-269 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:10] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 09:45:12,064 [Thread-270 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 09:45:12,963 [Thread-270 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 09:45:13,094 [Thread-270 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:13] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 09:45:13,277 [Thread-271 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:13] "GET /socket.io/?EIO=4&transport=polling&t=P2qcWrm HTTP/1.1" 200 -
# 2024-07-15 09:45:13,639 [Thread-273 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:13] "POST /socket.io/?EIO=4&transport=polling&t=P2qcWsj&sid=8JAX3TBJCR60ugPmAAAU HTTP/1.1" 200 -
# 2024-07-15 09:45:13,644 [Thread-275 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:13] "GET /socket.io/?EIO=4&transport=polling&t=P2qcWsl&sid=8JAX3TBJCR60ugPmAAAU HTTP/1.1" 200 -
# 2024-07-15 09:45:18,996 [Thread-278 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 09:45:18,998 [Thread-278 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:45:18] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 09:49:51,579 [Thread-274 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:49:51] "GET /socket.io/?EIO=4&transport=websocket&sid=8JAX3TBJCR60ugPmAAAU HTTP/1.1" 200 -
# 2024-07-15 09:51:34,396 [Thread-290 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:34] "GET /socket.io/?EIO=4&transport=polling&t=P2qdzpz HTTP/1.1" 200 -
# 2024-07-15 09:51:34,657 [Thread-292 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:34] "POST /socket.io/?EIO=4&transport=polling&t=P2qdzvW&sid=Bm4CZz3YpLqz_2w4AAAW HTTP/1.1" 200 -
# 2024-07-15 09:51:34,746 [Thread-293 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:34] "GET /socket.io/?EIO=4&transport=polling&t=P2qdzvY&sid=Bm4CZz3YpLqz_2w4AAAW HTTP/1.1" 200 -
# 2024-07-15 09:51:34,754 [Thread-295 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:34] "GET /socket.io/?EIO=4&transport=polling&t=P2qdz-W&sid=Bm4CZz3YpLqz_2w4AAAW HTTP/1.1" 200 -
# 2024-07-15 09:51:35,503 [Thread-294 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:35] "GET /socket.io/?EIO=4&transport=websocket&sid=Bm4CZz3YpLqz_2w4AAAW HTTP/1.1" 200 -
# 2024-07-15 09:51:36,649 [Thread-298 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:36] "GET /socket.io/?EIO=4&transport=polling&t=P2qd-NE HTTP/1.1" 200 -
# 2024-07-15 09:51:36,895 [Thread-300 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:36] "POST /socket.io/?EIO=4&transport=polling&t=P2qd-SD&sid=u8L-IaGDIQ_99rqaAAAY HTTP/1.1" 200 -
# 2024-07-15 09:51:36,961 [Thread-301 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:36] "GET /socket.io/?EIO=4&transport=polling&t=P2qd-SE&sid=u8L-IaGDIQ_99rqaAAAY HTTP/1.1" 200 -
# 2024-07-15 09:51:37,055 [Thread-304 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:37] "GET /socket.io/?EIO=4&transport=polling&t=P2qd-Xe&sid=u8L-IaGDIQ_99rqaAAAY HTTP/1.1" 200 -
# 2024-07-15 09:51:37,677 [Thread-302 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:37] "GET /socket.io/?EIO=4&transport=websocket&sid=u8L-IaGDIQ_99rqaAAAY HTTP/1.1" 200 -
# 2024-07-15 09:51:44,177 [Thread-306 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 09:51:44,938 [Thread-306 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 09:51:44,943 [Thread-306 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:44] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 09:51:45,512 [Thread-307 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qe0cG HTTP/1.1" 200 -
# 2024-07-15 09:51:45,907 [Thread-309 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:45] "POST /socket.io/?EIO=4&transport=polling&t=P2qe0dK&sid=1RD7ocA6vQTJndiSAAAa HTTP/1.1" 200 -
# 2024-07-15 09:51:45,945 [Thread-312 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qe0dS&sid=1RD7ocA6vQTJndiSAAAa HTTP/1.1" 200 -
# 2024-07-15 09:51:51,559 [Thread-315 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 09:51:51,559 [Thread-315 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:51] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 09:51:56,258 [Thread-316 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 09:51:56,977 [Thread-316 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 09:51:56,993 [Thread-316 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:51:56] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 09:52:02,256 [Thread-310 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 09:52:02] "GET /socket.io/?EIO=4&transport=websocket&sid=1RD7ocA6vQTJndiSAAAa HTTP/1.1" 200 -
# 2024-07-15 10:02:46,012 [Thread-317 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 10:02:46,594 [Thread-317 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 10:02:46,596 [Thread-317 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:02:46] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 10:02:48,174 [Thread-318 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:02:48] "GET /socket.io/?EIO=4&transport=polling&t=P2qgYMI HTTP/1.1" 200 -
# 2024-07-15 10:02:48,501 [Thread-320 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:02:48] "POST /socket.io/?EIO=4&transport=polling&t=P2qgYOf&sid=uCb1g2_73ZL8YhYuAAAc HTTP/1.1" 200 -
# 2024-07-15 10:02:48,522 [Thread-323 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:02:48] "GET /socket.io/?EIO=4&transport=polling&t=P2qgYOg&sid=uCb1g2_73ZL8YhYuAAAc HTTP/1.1" 200 -
# 2024-07-15 10:02:55,814 [Thread-325 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 10:02:55,817 [Thread-325 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:02:55] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 10:03:04,654 [Thread-321 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:03:04] "GET /socket.io/?EIO=4&transport=websocket&sid=uCb1g2_73ZL8YhYuAAAc HTTP/1.1" 200 -
# 2024-07-15 10:05:44,088 [Thread-326 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:44] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDGJ HTTP/1.1" 200 -
# 2024-07-15 10:05:44,729 [Thread-328 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:44] "POST /socket.io/?EIO=4&transport=polling&t=P2qhDUF&sid=IeHdLeZKdZJoB3-aAAAe HTTP/1.1" 200 -
# 2024-07-15 10:05:45,032 [Thread-330 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDUH&sid=IeHdLeZKdZJoB3-aAAAe HTTP/1.1" 200 -
# 2024-07-15 10:05:45,089 [Thread-333 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDVZ HTTP/1.1" 200 -
# 2024-07-15 10:05:45,412 [Thread-335 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "POST /socket.io/?EIO=4&transport=polling&t=P2qhDau&sid=1YlgY5A0ImW2druSAAAg HTTP/1.1" 200 -
# 2024-07-15 10:05:45,428 [Thread-338 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDav&sid=1YlgY5A0ImW2druSAAAg HTTP/1.1" 200 -
# 2024-07-15 10:05:45,538 [Thread-340 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDc- HTTP/1.1" 200 -
# 2024-07-15 10:05:45,666 [Thread-342 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "POST /socket.io/?EIO=4&transport=polling&t=P2qhDhw&sid=j1fm_ykympHw6OnzAAAi HTTP/1.1" 200 -
# 2024-07-15 10:05:45,874 [Thread-345 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDhx&sid=j1fm_ykympHw6OnzAAAi HTTP/1.1" 200 -
# 2024-07-15 10:05:45,899 [Thread-343 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:45] "GET /socket.io/?EIO=4&transport=polling&t=P2qhDnB&sid=j1fm_ykympHw6OnzAAAi HTTP/1.1" 200 -
# 2024-07-15 10:05:53,732 [Thread-344 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:05:53] "GET /socket.io/?EIO=4&transport=websocket&sid=j1fm_ykympHw6OnzAAAi HTTP/1.1" 200 -
# 2024-07-15 10:08:33,945 [Thread-329 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:08:33] "GET /socket.io/?EIO=4&transport=websocket&sid=IeHdLeZKdZJoB3-aAAAe HTTP/1.1" 200 -
# 2024-07-15 10:08:35,168 [Thread-336 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:08:35] "GET /socket.io/?EIO=4&transport=websocket&sid=1YlgY5A0ImW2druSAAAg HTTP/1.1" 200 -
# 2024-07-15 10:11:09,162 [Thread-360 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 10:11:09,911 [Thread-360 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 10:11:09,911 [Thread-360 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:09] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 10:11:10,668 [Thread-361 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:10] "GET /socket.io/?EIO=4&transport=polling&t=P2qiT42 HTTP/1.1" 200 -
# 2024-07-15 10:11:11,041 [Thread-363 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:11] "POST /socket.io/?EIO=4&transport=polling&t=P2qiT53&sid=tQu1S__sfATuBOb8AAAk HTTP/1.1" 200 -
# 2024-07-15 10:11:11,049 [Thread-366 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:11] "GET /socket.io/?EIO=4&transport=polling&t=P2qiT55&sid=tQu1S__sfATuBOb8AAAk HTTP/1.1" 200 -
# 2024-07-15 10:11:17,727 [Thread-368 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 10:11:18,311 [Thread-368 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 10:11:18,311 [Thread-368 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:18] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 10:11:21,577 [Thread-369 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 10:11:21,577 [Thread-369 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:21] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 10:11:29,491 [Thread-370 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 10:11:29,493 [Thread-370 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:29] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 10:11:43,901 [Thread-372 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 10:11:44,557 [Thread-372 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 10:11:44,559 [Thread-372 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:44] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 10:11:49,840 [Thread-373 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 10:11:49,842 [Thread-373 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:49] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 10:11:55,932 [Thread-364 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:11:55] "GET /socket.io/?EIO=4&transport=websocket&sid=tQu1S__sfATuBOb8AAAk HTTP/1.1" 200 -
# 2024-07-15 10:12:13,187 [Thread-374 (process_request_thread)] DEBUG: Starting new HTTPS connection (1): www.googleapis.com:443
# 2024-07-15 10:12:13,490 [Thread-375 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:13] "GET /socket.io/?EIO=4&transport=polling&t=P2qiiOm HTTP/1.1" 200 -
# 2024-07-15 10:12:13,840 [Thread-377 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:13] "POST /socket.io/?EIO=4&transport=polling&t=P2qiiQF&sid=-hz8vMd9Rssgngv6AAAm HTTP/1.1" 200 -
# 2024-07-15 10:12:13,840 [Thread-380 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:13] "GET /socket.io/?EIO=4&transport=polling&t=P2qiiQV&sid=-hz8vMd9Rssgngv6AAAm HTTP/1.1" 200 -
# 2024-07-15 10:12:14,038 [Thread-374 (process_request_thread)] DEBUG: https://www.googleapis.com:443 "GET /oauth2/v3/userinfo HTTP/1.1" 200 None
# 2024-07-15 10:12:14,038 [Thread-374 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:14] "POST /authenticate HTTP/1.1" 200 -
# 2024-07-15 10:12:17,437 [Thread-382 (process_request_thread)] INFO: THE CREDENTIALS ****** ------------->
# 2024-07-15 10:12:17,439 [Thread-382 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:17] "POST /set_credentials HTTP/1.1" 200 -
# 2024-07-15 10:12:22,901 [Thread-378 (process_request_thread)] INFO: 127.0.0.1 - - [15/Jul/2024 10:12:22] "GET /socket.io/?EIO=4&transport=websocket&sid=-hz8vMd9Rssgngv6AAAm HTTP/1.1" 200 -

# %%
from pprint import pprint
pprint(chat_history.buffer)
